# %% [markdown]
# <a href="https://colab.research.google.com/github/fhgqowfbeoufb/exp-1/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exp 1 : Introduction to Python
# Yogesh Shendage / 25070123128

# %%
a,b,c="Apple","Cherry","Orange"
print(a,b,c,sep="\n")
# Out:
# Apple
# Cherry
# Orange

# %%
v,x,y,z=2,2.5,"Yogesh",True
print(type(v),type(x),type(y),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("sum =",a+b,"\nsub =",a-b,"\nmult =",a*b,"\ndiv =",a/b,"\nexp =",a**b)
# Out:
# sum = 15
# sub = 5
# mult = 50
# div = 2.0
# exp = 100000

# %%
a=int(input("Enter the 1st Number: "))
b=int(input("Enter the 2nd Number: "))
print("sum =",a+b,"\nsub =",a-b,"\nmult =",a*b,"\ndiv =",a/b,"\nexp =",a**b)
# Out:
# Enter the 1st Number: 3
# Enter the 2nd Number: 3
# sum = 6
# sub = 0
# mult = 9
# div = 1.0
# exp = 27

# %%
#Area Of Circle
import math
r=float(input("Enter the Radius: "))
print("Area =",math.pi*(r**2))
# Out:
# Enter the Radius: 3
# Area = 28.274333882308138

# %%
#Log
import math
math.log10(10)
# Out:
# 1.0

# %%
#if else
a=int(input("Enter the 1st Number: "))
b=int(input("Enter the 2nd Number: "))
if a>b:
  print("a is greater than b")
  print("a is",a)
else:
  print("b is greater than a")
  print("b is",b)
# Out:
# Enter the 1st Number: 6
# Enter the 2nd Number: 3
# a is greater than b
# a is 6

# %%
def Calculator():
  while True:
    print("Enter '+' for Addition")
    print("Enter '-' for Substraction")
    print("Enter '*' for Multiplication")
    print("Enter '/' for Division")
    print("Enter 'quit' to end the program")
    operation= input("Enter Operand:")
    if operation == 'quit':
      break
    elif operation in['+','-','*','/']:
      a=int(input("Enter the 1st Number: "))
      b=int(input("Enter the 2nd Number: "))
      if operation == '+':
        print("sum:",a+b)
      elif operation == '-':
        print("sum:",a-b)
      elif operation == '*':
        print("sum:",a*b)
      elif operation == '/':
        print("sum:",a/b)
      else:
        print("Invalid Operation")
Calculator()
# Out:
# Enter '+' for Addition
# Enter '-' for Substraction
# Enter '*' for Multiplication
# Enter '/' for Division
# Enter 'quit' to end the program
# Enter Operand:5 + 3
# Enter '+' for Addition
# Enter '-' for Substraction
# Enter '*' for Multiplication
# Enter '/' for Division
# Enter 'quit' to end the program
# Enter Operand:5
# Enter '+' for Addition
# Enter '-' for Substraction
# Enter '*' for Multiplication
# Enter '/' for Division
# Enter 'quit' to end the program
# Enter Operand:+
# Enter the 1st Number: 5
# Enter the 2nd Number: 5
# sum: 10
# Enter '+' for Addition
# Enter '-' for Substraction
# Enter '*' for Multiplication
# Enter '/' for Division
# Enter 'quit' to end the program
